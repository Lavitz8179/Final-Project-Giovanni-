# %%
MH_12 DATASET

# %%
import pandas as pd
import numpy as np
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.metrics import mean_squared_error

# %matplotlib inline
import matplotlib
import datetime

# %% [markdown]
# MH_12

# %%
# path Giovanni
df=pd.read_csv(r"C:\Users\giova\Desktop\Boolean\Files\Slide\Modulo 6 - Final Project & Career Service\Global suicide data/MH_12.csv")
df
# Out:
#          Country          Sex  2015  2010  2005  2000
# 0    Afghanistan   Both sexes   7.1   7.0   7.3   6.7
# 1    Afghanistan         Male  10.9  11.1  11.7  10.9
# 2    Afghanistan       Female   3.1   2.8   2.6   2.3
# 3        Albania   Both sexes   3.8   5.0   6.5   6.4
# 4        Albania         Male   5.3   7.3   9.5   9.8
# ..           ...          ...   ...   ...   ...   ...
# 544       Zambia         Male  18.2  18.3  18.5  21.2
# 545       Zambia       Female   5.0   5.2   5.2   6.2
# 546     Zimbabwe   Both sexes  18.0  18.7  19.0  20.4
# 547     Zimbabwe         Male  26.9  28.5  29.3  30.7
# 548     Zimbabwe       Female  10.3  10.2  10.0  11.1
#
# [549 rows x 6 columns]

# %%
# path Silvia
df=pd.read_csv("C:/Users/User/Desktop/BOOLEAN/FINAL PROJ/FAI QUESTO/MH_12.csv")
df.head(20)
# Out:
#                 Country          Sex  2015  2010  2005  2000
# 0           Afghanistan   Both sexes   7.1   7.0   7.3   6.7
# 1           Afghanistan         Male  10.9  11.1  11.7  10.9
# 2           Afghanistan       Female   3.1   2.8   2.6   2.3
# 3               Albania   Both sexes   3.8   5.0   6.5   6.4
# 4               Albania         Male   5.3   7.3   9.5   9.8
# 5               Albania       Female   2.4   2.8   3.6   3.1
# 6               Algeria   Both sexes   3.1   3.4   3.8   3.5
# 7               Algeria         Male   5.0   5.3   5.4   4.8
# 8               Algeria       Female   1.3   1.4   2.1   2.3
# 9                Angola   Both sexes  25.9  26.2  25.6  23.8
# 10               Angola         Male  38.1  38.8  38.5  36.3
# 11               Angola       Female  14.3  14.3  13.3  12.0
# 12  Antigua and Barbuda   Both sexes   0.0   0.2   1.5   2.2
# 13  Antigua and Barbuda         Male   0.0   0.4   3.2   4.6
# ...

# %%
# niente valori NaN
df[pd.isna(df.Country)]
# Out:
# Empty DataFrame
# Columns: [Country, Sex, 2015, 2010, 2005, 2000]
# Index: []

# %%
# datatype a posto
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  549 non-null    object
#  1   Sex      549 non-null    object
#  2   2015     549 non-null    float64
#  3   2010     549 non-null    float64
#  4   2005     549 non-null    float64
#  5   2000     549 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 25.9+ KB

# %%
df["2015"].dtype
# Out:
# dtype('float64')

# %%
# path Giovanni
df1=pd.read_csv(r"C:\Users\giova\Desktop\Boolean\Files\Slide\Modulo 6 - Final Project & Career Service\Global suicide data/SDGSUICIDE.csv")
df1
# Out:
#       Unnamed: 0   Unnamed: 1  Crude suicide rates (per 100 000 population)  \
# 0        Country          Sex                                        2015.0
# 1    Afghanistan   Both sexes                                           5.5
# 2    Afghanistan         Male                                           8.3
# 3    Afghanistan       Female                                           2.6
# 4        Albania   Both sexes                                           4.3
# ..           ...          ...                                           ...
# 545       Zambia         Male                                           9.9
# 546       Zambia       Female                                           2.9
# 547     Zimbabwe   Both sexes                                          10.5
# 548     Zimbabwe         Male                                          15.6
# 549     Zimbabwe       Female                                           5.6
#
#      Crude suicide rates (per 100 000 population).1  \
# ...

# %% [markdown]
# SDGSUICIDE

# %%
# path Silvia
df1=pd.read_csv("C:/Users/User/Desktop/BOOLEAN/FINAL PROJ/FAI QUESTO/SDGSUICIDE.csv")
df1.head(20)
# Out:
#              Unnamed: 0   Unnamed: 1  \
# 0               Country          Sex
# 1           Afghanistan   Both sexes
# 2           Afghanistan         Male
# 3           Afghanistan       Female
# 4               Albania   Both sexes
# 5               Albania         Male
# 6               Albania       Female
# 7               Algeria   Both sexes
# 8               Algeria         Male
# 9               Algeria       Female
# 10               Angola   Both sexes
# 11               Angola         Male
# 12               Angola       Female
# 13  Antigua and Barbuda   Both sexes
# 14  Antigua and Barbuda         Male
# 15  Antigua and Barbuda       Female
# 16            Argentina   Both sexes
# 17            Argentina         Male
# 18            Argentina       Female
# 19              Armenia   Both sexes
#
#     Crude suicide rates (per 100 000 population)  \
# 0                                         2015.0
# 1                                            5.5
# ...

# %%
# drop della riga di indice 0
df1 = df1.drop(index=0)

# %%
df1.head()
# Out:
#     Unnamed: 0   Unnamed: 1  Crude suicide rates (per 100 000 population)  \
# 1  Afghanistan   Both sexes                                           5.5
# 2  Afghanistan         Male                                           8.3
# 3  Afghanistan       Female                                           2.6
# 4      Albania   Both sexes                                           4.3
# 5      Albania         Male                                           5.9
#
#    Crude suicide rates (per 100 000 population).1  \
# 1                                             5.2
# 2                                             8.0
# 3                                             2.2
# 4                                             5.3
# 5                                             7.6
#
#    Crude suicide rates (per 100 000 population).2  \
# 1                                             5.4
# 2                                             8.6
# 3                                             2.0
# ...

# %%
# rename colonne
df1 = df1.rename(columns={'Unnamed: 0': 'Country', 'Unnamed: 1': 'Sex','Crude suicide rates (per 100 000 population)': 'Crude suicide rate 2015', 'Crude suicide rates (per 100 000 population).1': 'Crude suicide rate 2010', 'Crude suicide rates (per 100 000 population).2': 'Crude suicide rate 2005', 'Crude suicide rates (per 100 000 population).3': 'Crude suicide rate 2000' })

# %%
df1.head()
# Out:
#        Country          Sex  Crude suicide rate 2015  Crude suicide rate 2010  \
# 1  Afghanistan   Both sexes                      5.5                      5.2
# 2  Afghanistan         Male                      8.3                      8.0
# 3  Afghanistan       Female                      2.6                      2.2
# 4      Albania   Both sexes                      4.3                      5.3
# 5      Albania         Male                      5.9                      7.6
#
#    Crude suicide rate 2005  Crude suicide rate 2000
# 1                      5.4                      4.8
# 2                      8.6                      7.8
# 3                      2.0                      1.7
# 4                      6.3                      6.0
# 5                      9.0                      8.9

# %%
# niente valori NaN
df1[pd.isna(df1.Country)]
# Out:
# Empty DataFrame
# Columns: [Country, Sex, crude suicide rate 2015, crude suicide rate 2010, crude suicide rate 2005, crude suicide rate 2000]
# Index: []

# %%
df1[pd.isna(df1["crude suicide rate 2015"])]
# Out:
# Empty DataFrame
# Columns: [Country, Sex, crude suicide rate 2015, crude suicide rate 2010, crude suicide rate 2005, crude suicide rate 2000]
# Index: []

# %% [markdown]
# SUICIDE RATES BY COUNTRY

# %%
# path Giovanni
df2=pd.read_csv(r"C:\Users\giova\Desktop\Boolean\Files\Slide\Modulo 6 - Final Project & Career Service\Global suicide data/suicide-rates-by-country.csv")
df2
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2002
# 1     Afghanistan  AFG  2004
# 2     Afghanistan  AFG  2005
# 3         Albania  ALB  2002
# 4         Albania  ALB  2004
# ...           ...  ...   ...
# 2838       Zambia  ZMB  2004
# 2839       Zambia  ZMB  2005
# 2840     Zimbabwe  ZWE  2002
# 2841     Zimbabwe  ZWE  2004
# 2842     Zimbabwe  ZWE  2005
#
#       suicide rate (age-adjusted suicides per 100,000 people)
# 0                                              6.867054
# 1                                              6.684385
# 2                                              6.684385
# 3                                              2.792918
# 4                                              7.699330
# ...                                                 ...
# 2838                                          12.019036
# 2839                                          12.019036
# 2840                                           7.541058
# ...

# %%
# path Silvia
df2=pd.read_csv("C:/Users/User/Desktop/BOOLEAN/FINAL PROJ/FAI QUESTO/suicide-rates-by-country.csv")
df2.head(20)
# Out:
#                  Entity Code  Year  \
# 0           Afghanistan  AFG  2002
# 1           Afghanistan  AFG  2004
# 2           Afghanistan  AFG  2005
# 3               Albania  ALB  2002
# 4               Albania  ALB  2004
# 5               Albania  ALB  2005
# 6               Algeria  DZA  2002
# 7               Algeria  DZA  2004
# 8               Algeria  DZA  2005
# 9               Andorra  AND  2002
# 10              Andorra  AND  2004
# 11              Andorra  AND  2005
# 12               Angola  AGO  2002
# 13               Angola  AGO  2004
# 14               Angola  AGO  2005
# 15  Antigua and Barbuda  ATG  2002
# 16  Antigua and Barbuda  ATG  2004
# 17  Antigua and Barbuda  ATG  2005
# 18            Argentina  ARG  1966
# 19            Argentina  ARG  1967
#
#     suicide rate (age-adjusted suicides per 100,000 people)
# 0                                            6.867054
# 1                                            6.684385
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2843 entries, 0 to 2842
# Data columns (total 4 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Entity                                                   2843 non-null   object
#  1   Code                                                     2843 non-null   object
#  2   Year                                                     2843 non-null   int64
#  3   suicide rate (age-adjusted suicides per 100,000 people)  2843 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 89.0+ KB

# %%
# niente valori NaN
df2[pd.isna(df2.Entity)]
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, suicide rate (age-adjusted suicides per 100,000 people)]
# Index: []

# %%
df2[pd.isna(df2["suicide rate (age-adjusted suicides per 100,000 people)"])]
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, suicide rate (age-adjusted suicides per 100,000 people)]
# Index: []

# %%
df2["Year"].dtype
# Out:
# dtype('int32')

# %%
df2["Year"]= df2["Year"].astype(int)

# %%
df2["Year"] = pd.to_datetime(df2["Year"], format='%Y')
df2.head()
# Out:
#         Entity Code       Year  \
# 0  Afghanistan  AFG 2002-01-01
# 1  Afghanistan  AFG 2004-01-01
# 2  Afghanistan  AFG 2005-01-01
# 3      Albania  ALB 2002-01-01
# 4      Albania  ALB 2004-01-01
#
#    suicide rate (age-adjusted suicides per 100,000 people)
# 0                                           6.867054
# 1                                           6.684385
# 2                                           6.684385
# 3                                           2.792918
# 4                                           7.699330

# %%
df2['year'] = df2['Year'].dt.year

# Drop the original date column
df2 = df2.drop(columns=['Year'])
df2.head()
# Out:
#         Entity Code  suicide rate (age-adjusted suicides per 100,000 people)  \
# 0  Afghanistan  AFG                                           6.867054
# 1  Afghanistan  AFG                                           6.684385
# 2  Afghanistan  AFG                                           6.684385
# 3      Albania  ALB                                           2.792918
# 4      Albania  ALB                                           7.699330
#
#    year
# 0  2002
# 1  2004
# 2  2005
# 3  2002
# 4  2004

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2843 entries, 0 to 2842
# Data columns (total 4 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Entity                                                   2843 non-null   object
#  1   Code                                                     2843 non-null   object
#  2   suicide rate (age-adjusted suicides per 100,000 people)  2843 non-null   float64
#  3   year                                                     2843 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 89.0+ KB

# %% [markdown]
# MALE FEMALE RATIO

# %%
# path Giovanni
df3=pd.read_csv(r"C:\Users\giova\Desktop\Boolean\Files\Slide\Modulo 6 - Final Project & Career Service\Global suicide data/Male-Female-Ratio-of-Suicide-Rates.csv")
df3
# Out:
#            Entity      Code  Year  Male-Female Ratio of Suicide Rate
# 0     Afghanistan       AFG  2004                           0.566016
# 1         Albania       ALB  2004                           1.539476
# 2         Algeria       DZA  2004                           1.118298
# 3         Andorra       AND  2004                           2.772599
# 4          Angola       AGO  2004                           2.636721
# ...           ...       ...   ...                                ...
# 2499   Yugoslavia  OWID_YGS  1988                           2.527963
# 2500   Yugoslavia  OWID_YGS  1989                           2.631449
# 2501   Yugoslavia  OWID_YGS  1990                           2.669948
# 2502       Zambia       ZMB  2004                           2.077427
# 2503     Zimbabwe       ZWE  2004                           2.008948
#
# [2504 rows x 4 columns]

# %%
# path Silvia
df3=pd.read_csv("C:/Users/User/Desktop/BOOLEAN/FINAL PROJ/FAI QUESTO/Male-Female-Ratio-of-Suicide-Rates.csv")
df3.head(20)
# Out:
#          Entity Code  Year  Male-Female Ratio of Suicide Rate
# 0   Afghanistan  AFG  2004                           0.566016
# 1       Albania  ALB  2004                           1.539476
# 2       Algeria  DZA  2004                           1.118298
# 3       Andorra  AND  2004                           2.772599
# 4        Angola  AGO  2004                           2.636721
# 5     Argentina  ARG  1966                           3.233862
# 6     Argentina  ARG  1967                           3.439053
# 7     Argentina  ARG  1968                           3.390132
# 8     Argentina  ARG  1969                           3.750769
# 9     Argentina  ARG  1970                           3.154567
# 10    Argentina  ARG  1977                           2.861354
# 11    Argentina  ARG  1978                           2.844377
# 12    Argentina  ARG  1979                           2.706615
# 13    Argentina  ARG  1980                           2.975403
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2504 entries, 0 to 2503
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Entity                             2504 non-null   object
#  1   Code                               2504 non-null   object
#  2   Year                               2504 non-null   int64
#  3   Male-Female Ratio of Suicide Rate  2504 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 78.4+ KB

# %%
# niente valori NaN
df3[pd.isna(df3.Code)]
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Male-Female Ratio of Suicide Rate]
# Index: []

# %%
df3[pd.isna(df3["Male-Female Ratio of Suicide Rate"])]
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Male-Female Ratio of Suicide Rate]
# Index: []

# %%
df3["Year"].dtype
# Out:
# dtype('int64')

# %%
df3["Year"]= df3["Year"].astype(int)

# %%
df3["Year"] = pd.to_datetime(df3["Year"], format='%Y')
df3.head()
# Out:
#         Entity Code       Year  Male-Female Ratio of Suicide Rate
# 0  Afghanistan  AFG 2004-01-01                           0.566016
# 1      Albania  ALB 2004-01-01                           1.539476
# 2      Algeria  DZA 2004-01-01                           1.118298
# 3      Andorra  AND 2004-01-01                           2.772599
# 4       Angola  AGO 2004-01-01                           2.636721

# %%
df3['year'] = df3['Year'].dt.year

# Drop the original date column
df3 = df3.drop(columns=['Year'])
df3.head()
# Out:
#         Entity Code  Male-Female Ratio of Suicide Rate  year
# 0  Afghanistan  AFG                           0.566016  2004
# 1      Albania  ALB                           1.539476  2004
# 2      Algeria  DZA                           1.118298  2004
# 3      Andorra  AND                           2.772599  2004
# 4       Angola  AGO                           2.636721  2004

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2504 entries, 0 to 2503
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Entity                             2504 non-null   object
#  1   Code                               2504 non-null   object
#  2   Male-Female Ratio of Suicide Rate  2504 non-null   float64
#  3   year                               2504 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 78.4+ KB

# %% [markdown]
# **df** = MH_12
# **df1** = SDGSUICIDE
# **df2** = SUICIDE RATES BY COUNTRY
# **df3** = MALE FEMALE RATIO

# %%
# esportazione file Giovanni
df = df.to_excel(r'C:\Users\giova\Desktop\Github Final Project\Dataset puliti\MH_12.xlsx')

# %%
df1= df1.to_excel(r'C:\Users\giova\Desktop\Github Final Project\Dataset puliti\Global suicide data\SDGSUCIDE.xlsx')

# %%
df2= df2.to_excel(r'C:\Users\giova\Desktop\Github Final Project\Dataset puliti\Global suicide data\suicide-rates-by-country.xlsx')

# %%
df3= df3.to_excel(r'C:\Users\giova\Desktop\Github Final Project\Dataset puliti\Global suicide data\Male-Female-Ratio-of-Suicide-Rates.xlsx')
